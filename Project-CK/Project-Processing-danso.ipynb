# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Mar 29 01:01:59 2019

@author: Chuong Pham
"""

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

df = pd.read_csv('danso.csv')
print(df)
################
# Out:
#      Nam     DanSo  PTThayDoi  ThayDoi    DiCu  TuoiTB  TiLeSinh  MatDo  \
# 0   2017  95414640       1.03   970440  -40000    30.8      1.96    308
# 1   2016  94444200       1.07   996599  -40000    30.8      1.96    305
# 2   2015  93447601       1.13  1017965  -40000    30.0      1.96    301
# 3   2010  88357775       0.97   830792 -175500    29.0      1.93    285
# 4   2005  84203817       0.96   783651 -154500    26.0      1.92    272
# 5   2000  80285563       1.32  1017318  -43200    24.0      2.25    259
# 6   1995  75198975       1.97  1397874  -78800    22.0      3.23    243
# 7   1990  68209604       2.24  1432047  -66500    21.0      3.85    220
# 8   1985  61049370       2.34  1335370  -65000    20.0      4.60    197
# 9   1980  54372518       2.22  1128624 -162600    19.0      5.50    175
# 10  1975  48729397       2.34  1064421       0    18.0      6.33    157
# 11  1970  43407291       2.77  1109455       0    18.0      6.46    140
# ...

# %%
plt.figure(figsize =(10,7,))
sns.barplot(x='Nam', y='DiCu', palette="rocket",data=df)
#df['dicu'] = df['DiCu'].replace('-','')

# %%
plt.figure(figsize =(10,7))
#sns.countplot(x='District Name',data=df,palette='viridis')
sns.barplot(x='Nam', y='DanSo', palette="rocket",data=df)

# %%
plt.figure(figsize =(10,7))
#sns.countplot(x='District Name',data=df,palette='viridis')
sns.barplot(x='Nam', y='ThayDoi', palette="rocket",data=df)

# %%
plt.figure(figsize =(10,7))
#sns.countplot(x='District Name',data=df,palette='viridis')
sns.barplot(x='Nam', y='DanThanhThi', palette="rocket",data=df)
